# %% [markdown]
# Permisos esquema y catalogos

# %%
# %sql
GRANT ALL PRIVILEGES ON CATALOG apple_production TO `DataEnginers`;
GRANT CREATE, USE SCHEMA ON SCHEMA  apple_production.bronze to `DataEnginers`;
GRANT CREATE, USE SCHEMA ON SCHEMA  apple_production.silver to `DataEnginers`;
GRANT CREATE, USE SCHEMA ON SCHEMA  apple_production.golden to `DataEnginers`;

# %% [markdown]
# Permisos external location

# %%
# %sql
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-data` to `DataEnginers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-bronze` to `DataEnginers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-silver` to `DataEnginers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-golden` to `DataEnginers`;
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION `exlt-raw` to `DataEnginers`;
