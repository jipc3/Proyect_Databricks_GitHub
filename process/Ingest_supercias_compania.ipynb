# %% [markdown]
# ## LIBRARIES

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# ## WIDGETS

# %%
# %python
dbutils.widgets.removeAll()

# %%
dbutils.widgets.text("storageName", "saccexplorer")
dbutils.widgets.text("containerName", "bronze")
dbutils.widgets.text("catalogName", "unit_catalog_explorer")
dbutils.widgets.text("schemaName", "uc_bronze")

# %% [markdown]
# ## CONSTANTS

# %%
storage = dbutils.widgets.get("storageName")
container = dbutils.widgets.get("containerName")
catalog =  dbutils.widgets.get("catalogName")
schema =  dbutils.widgets.get("schemaName")

# %% [markdown]
# ## PATHS

# %%
path_base_bronze = f"abfss://{container}@{storage}.dfs.core.windows.net/{schema}"

path_compania = f"{path_base_bronze}/supercias_compania"

# %% [markdown]
# ## SOURCES

# %%
# --- (URLs de Supercias Ecuador) ---
url_compania = "https://appscvsmovil.supercias.gob.ec/ranking/recursos/bi_compania.csv"

# %% [markdown]
# ## STRUCTURES

# %%
# import pandas as pd
# df_compania = pd.read_csv(url_compania)
# print(df_compania.dtypes)


compania_schema = StructType([
    StructField("expediente", IntegerType(), True),
    StructField("ruc", StringType(), True),
    StructField("nombre", StringType(), True),
    StructField("tipo", StringType(), True),
    StructField("pro_codigo", IntegerType(), True),
    StructField("provincia", StringType(), True)
])

# %% [markdown]
# ## READ SOURCE

# %%
# --- Descarga del archivo (Lectura directa desde el driver)
import requests

temp_local_path = "/tmp/compania_temp.csv"
response = requests.get(url_compania, verify=False) 

if response.status_code == 200:
    with open(temp_local_path, "wb") as f:
        f.write(response.content)
    print("Archivo descargado localmente en el Driver.")
else:
    raise Exception(f"Error al descargar: {response.status_code}")


# %sh ls -lh /tmp/

# %% [markdown]
# ## SAVE SOURCE

# %%
# --- Lectura con Spark
df_compania = (spark.read
              .option("header", "True")
              .option("delimiter", ",") 
              .schema(compania_schema)
              .csv(f"file:{temp_local_path}")) 

# --- Escritura a Delta (Unity Catalog)
df_compania.write.format("delta") \
    .mode("overwrite") \
    .option("path", path_compania) \
    .saveAsTable(f"{catalog}.{schema}.supercias_compania")

print(f"¡Éxito! Tabla creada en {catalog}.{schema}.supercias_compania")


# --- BLOQUE DE LIMPIEZA ---
import os
if os.path.exists(temp_local_path):
    os.remove(temp_local_path)
    print(f"Archivo temporal {temp_local_path} eliminado del Driver.")


# %sh ls -lh /tmp/
